# %% [markdown]
# <a href="https://colab.research.google.com/github/Charish53/RL_lab/blob/main/LAB02/Temporal_Difference_Learning(TDL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
